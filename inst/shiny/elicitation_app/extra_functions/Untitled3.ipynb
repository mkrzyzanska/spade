# %% [markdown]
# nsquares=2-
#
# square_width=1
#
# area=1

# %%
a<-c(0,0,0,1,2,4,0)

# %%
min(which(a!=0))
# Out:
# [1] 4

# %%
nsquares=20

square_width=1

area=1

# %%
square_height = area/(square_width*nsquares)

# %%
square_height
# Out:
# [1] 0.05

# %%
?scale_y_continous
# Out:
# No documentation for ‘scale_y_continous’ in specified packages and libraries:
# you could try ‘??scale_y_continous’

# %%
### Area is always 1
### The numbe of squarea and the square with decides the square height

# %%
?geom_rect
# Out:
# No documentation for ‘geom_rect’ in specified packages and libraries:
# you could try ‘??geom_rect’

# %%
d<-data.frame(xmin=c(1,1,2,3,4),xmax=c(2,2,3,4,5),ymin=c(1,2,2,3,4),ymax=c(2,3,3,4,5))

# %%
d
# Out:
#   xmin xmax ymin ymax
# 1 1    2    1    2
# 2 1    2    2    3
# 3 2    3    2    3
# 4 3    4    3    4
# 5 4    5    4    5

# %%
ggplot(data=d,aes(xmin = d$xmin, xmax = d$xmax, 
                                     ymin = d$ymin, ymax = d$ymax))+
geom_rect()
# Out:
# Warning message:
# “Use of `d$xmin` is discouraged.
# ℹ Use `xmin` instead.”
# Warning message:
# “Use of `d$xmax` is discouraged.
# ℹ Use `xmax` instead.”
# Warning message:
# “Use of `d$ymin` is discouraged.
# ℹ Use `ymin` instead.”
# Warning message:
# “Use of `d$ymax` is discouraged.
# ℹ Use `ymax` instead.”
# plot without title

# %%
rectangles<-d

# %%
dat<-data.frame(x=c(0,1,2,3,4),fx=c(0,1,2,3,4))

# %%
ggplot(dat,aes(x=x,y=x))+
geom_point()+
geom_rect( data = rectangles,inherit.aes=FALSE,aes(xmin = rectangles$xmin, xmax = rectangles$xmax, 
                                     ymin = rectangles$ymin, ymax = rectangles$ymax), 
            fill = "blue", color = "black", alpha = 0.5)
# Out:
# Warning message:
# “Use of `rectangles$xmin` is discouraged.
# ℹ Use `xmin` instead.”
# Warning message:
# “Use of `rectangles$xmax` is discouraged.
# ℹ Use `xmax` instead.”
# Warning message:
# “Use of `rectangles$ymin` is discouraged.
# ℹ Use `ymin` instead.”
# Warning message:
# “Use of `rectangles$ymax` is discouraged.
# ℹ Use `ymax` instead.”
# plot without title

# %%
# Check what's up with using a lot of point:

# %%
### Try sorting out those values when have internet and see if it helps

extended_vals<-c(0,30,35,40,45,50,55,60,27.5,32.5,37.5,42.5,47.5,52.5,57.5,62.5,100)
extended_cumsums<-c(0,0.321428571428571,0.464285714285714,0.607142857142857,0.642857142857143,0.785714285714286,0.892857142857143,0.964285714285714,0.160714285714286,0.303571428571429,0.446428571428571,0.482142857142857,0.625,0.732142857142857,0.803571428571429,1.125,0)

# %%
v<-0.642857142857143-0.607142857142857

# %%
?xaxp
# Out:
# No documentation for ‘xaxp’ in specified packages and libraries:
# you could try ‘??xaxp’

# %%
ltp=3
extra_left_vals <- seq(extended_vals[1], extended_vals[2], length.out = ltp)[-1]

# %%
extra_left_vals
# Out:
# [1] 15 30

# %%
# Modify cdf to also work with splines

# %%
library("ggplot2")

# %%
?optim
# Out:
# optim                  package:stats                   R Documentation
#
# n
#
# n:
#
#      General-purpose optimization based on Nelder-Mead, quasi-Newton
#      and conjugate-gradient algorithms. It includes an option for
#      box-constrained optimization and simulated annealing.
#
# e:
#
#      optim(par, fn, gr = NULL, ...,
#            method = c("Nelder-Mead", "BFGS", "CG", "L-BFGS-B", "SANN",
#                       "Brent"),
#            lower = -Inf, upper = Inf,
#            control = list(), hessian = FALSE)
#
#      optimHess(par, fn, gr = NULL, ..., control = list())
#
# s:
#
#      par: Initial values for the parameters to be optimized over.
#
#       fn: A function to be minimized (or maximized), with first
#           argument the vector of parameters over which minimization is
#           to take place.  It should return a scalar result.
#
#       gr: A function to return the gradient for the ‘"BFGS"’, ‘"CG"’
# ...

# %%
abs(-2)
# Out:
# [1] 2

# %%
x<-c(0,0.948275862068966,1.89655172413793,2.8448275862069,3.79310344827586,4.74137931034483,5.68965517241379,6.63793103448276,7.58620689655172,8.53448275862069,9.48275862068965,10.4310344827586,11.3793103448276,12.3275862068966,13.2758620689655,14.2241379310345,15.1724137931034,16.1206896551724,17.0689655172414,18.0172413793103,18.9655172413793,19.9137931034483,20.8620689655172,21.8103448275862,22.7586206896552,23.7068965517241,24.6551724137931,25.6034482758621,26.551724137931,27.5,27.5,30,32.5,35,37.5,40,42.5,45,47.5,50,52.5,55,57.5,58.9655172413793,60.4310344827586,61.8965517241379,63.3620689655172,64.8275862068966,66.2931034482759,67.7586206896552,69.2241379310345,70.6896551724138,72.1551724137931,73.6206896551724,75.0862068965517,76.551724137931,78.0172413793103,79.4827586206897,80.948275862069,82.4137931034483,83.8793103448276,85.3448275862069,86.8103448275862,88.2758620689655,89.7413793103448,91.2068965517241,92.6724137931034,94.1379310344828,95.6034482758621,97.0689655172414,98.5344827586207,100,100)

# %%
y<-c(0,0.127801536987167,0.129019212450308,0.130248489757749,0.131489479450268,0.132742293121858,0.134007043429764,0.135283844104617,0.136572809960654,0.137874056906049,0.13918770195333,0.140513863229908,0.141852659988692,0.143204212618821,0.14456864265648,0.145946072795837,0.147336626900074,0.148740430012521,0.150157608367906,0.151588289403705,0.153032601771598,0.154490675349043,0.155962641250951,0.157448631841479,0.158948780745929,0.160463222862771,0.161992094375764,0.163535532766211,0.165093676825316,0.166666666666667,0.166666666666667,0.333333333333333,0.314814814814815,0.481481481481481,0.462962962962963,0.62962962962963,0.537037037037037,0.703703703703704,0.648148148148148,0.814814814814815,0.759259259259259,0.925925925925926,0.981481481481481,0.981750894593519,0.98201638820061,0.98227801932492,0.982535844159038,0.982789918078046,0.983040295651413,0.983287030654714,0.98353017608118,0.983769784153081,0.98400590633294,0.98423859333459,0.98446789513406,0.984693860980315,0.98491653940583,0.985135978237015,0.985352224604485,0.985565324953187,0.98577532505237,0.98598227000542,0.986186204259543,0.986387171615316,0.986585215236088,0.986780377657259,0.986972700795406,0.987162225957294,0.987348993848744,0.987533044583376,0.987714417691223,0.987893152127225,1)

# %%
plot(y~x)
# Out:
# plot without title

# %%
x<-c(0,27.5,30,32.5,35,37.5,40,42.5,45,47.5,50,52.5,55,57.5,100)
y<-c(0,0.166666666666667,0.333333333333333,0.314814814814815,0.481481481481481,0.462962962962963,0.62962962962963,0.537037037037037,0.703703703703704,0.648148148148148,0.814814814814815,0.759259259259259,0.925925925925926,0.981481481481481,0)

# %%
plot(y~x)
# Out:
# plot without title

# %%
0.333333333333333/2
# Out:
# [1] 0.1666667

# %%
### So this need to be adjusted so that each mid-point has a right value
(0.481481481481481-0.333333333333333)/2
# Out:
# [1] 0.07407407

# %%
# Given cumulative sum list
cumsum_list <- c(3, 7, 12, 18, 25)  

# Compute midpoints
midpoints <- c(cumsum_list[1] / 2, cumsum_list[-1] - diff(cumsum_list) / 2)

# Print result
print(midpoints)
# Out:
# [1]  1.5  5.0  9.5 15.0 21.5

# %%
mid_points
# Out:
# Error in eval(expr, envir, enclos): object 'mid_points' not found
# Traceback:

# %%
cumsum_list[-1]
# Out:
# [1]  7 12 18 25

# %%
diff(cumsum_list)/2
# Out:
# [1] 2.0 2.5 3.0 3.5

# %%
x<-c(0,17.5,20,22.5,25,27.5,30,32.5,35,37.5,40,42.5,45,47.5,50,52.5,55,57.5,60,62.5,100)

# %%
(0.941176470588235-0.882352941176471)/2
# Out:
# [1] 0.02941176

# %%
0.882352941176471+0.029411764705882
# Out:
# [1] 0.9117647

# %%
seq(40,100,length.out=2)
# Out:
# [1]  40 100

# %%
x<-c(0,0.277777777777778,0.555555555555556,0.833333333333333,1.11111111111111,1.38888888888889,1.66666666666667,1.94444444444444,2.22222222222222,2.5,2.77777777777778,3.05555555555556,3.33333333333333,3.61111111111111,3.88888888888889,4.16666666666667,4.44444444444444,4.72222222222222,5,5.27777777777778,5.55555555555556,5.83333333333333,6.11111111111111,6.38888888888889,6.66666666666667,6.94444444444444,7.22222222222222,7.5,7.77777777777778,8.05555555555556,8.33333333333333,8.61111111111111,8.88888888888889,9.16666666666667,9.44444444444444,9.72222222222222,10,10.2777777777778,10.5555555555556,10.8333333333333,11.1111111111111,11.3888888888889,11.6666666666667,11.9444444444444,12.2222222222222,12.5,12.7777777777778,13.0555555555556,13.3333333333333,13.6111111111111,13.8888888888889,14.1666666666667,14.4444444444444,14.7222222222222,15,15.2777777777778,15.5555555555556,15.8333333333333,16.1111111111111,16.3888888888889,16.6666666666667,16.9444444444444,17.2222222222222,17.5,17.7777777777778,18.0555555555556,18.3333333333333,18.6111111111111,18.8888888888889,19.1666666666667,19.4444444444444,19.7222222222222,20,20.2777777777778,20.5555555555556,20.8333333333333,21.1111111111111,21.3888888888889,21.6666666666667,21.9444444444444,22.2222222222222,22.5,22.7777777777778,23.0555555555556,23.3333333333333,23.6111111111111,23.8888888888889,24.1666666666667,24.4444444444444,24.7222222222222,25,25.2777777777778,25.5555555555556,25.8333333333333,26.1111111111111,26.3888888888889,26.6666666666667,26.9444444444444,27.2222222222222,27.5,27.5,30,32.5,35,37.5,40,42.5,45,47.5,50,52.5,55,57.5,57.9292929292929,58.3585858585859,58.7878787878788,59.2171717171717,59.6464646464646,60.0757575757576,60.5050505050505,60.9343434343434,61.3636363636364,61.7929292929293,62.2222222222222,62.6515151515151,63.0808080808081,63.510101010101,63.9393939393939,64.3686868686869,64.7979797979798,65.2272727272727,65.6565656565657,66.0858585858586,66.5151515151515,66.9444444444444,67.3737373737374,67.8030303030303,68.2323232323232,68.6616161616162,69.0909090909091,69.520202020202,69.9494949494949,70.3787878787879,70.8080808080808,71.2373737373737,71.6666666666667,72.0959595959596,72.5252525252525,72.9545454545455,73.3838383
0.903911147309242,0.904322765802987,0.904732621035128,0.905140720559,0.905547071895578,0.905951682533622,0.906354559929809,0.906755711508877,0.907155144663756,0.907552866755708,0.90794888511446,0.908343207038343,0.90873583979442,0.909126790618628,0.909516066715905,0.909903675260325,0.910289623395231,0.910673918233365,0.911056566857001,0.911437576318073,0.911816953638308,0.912194705809354,0.912570839792906,0.912945362520839,0.913318280895335,0.913689601789007,0.914059332045028,0.914427478477256,0.914794047870362,0.915159046979952,0.915522482532693,0.915884361226438,0.916244689730346,0.916603474685009,0.916960722702572,0.917316440366855,0.917670634233475,0.918023310829966,0.918374476655901,0.91872413818301,0.919072301855299,0.919418974089171,0.919764161273542,0.920107869769961,0.920450105912723,0.920790876008991,0.921130186338909,0.92146804315572,0.921804452685877,0.922139421129163,0.922472954658801,0.922805059421572,0.923135741537924,0.923465007102086,0.923792862182183,0.924119312820345,0.924444365032818,0.924768024810078,0.925090298116939,0.925411190892662,0.925730709051066,0.926048858480639,0.926365645044641,0.926681074581219,0.926995152903509,0.927307885799744,0.927619279033363,0.927929338343118,0.928238069443174,0.928545478023221,0.928851569748574,0.92915635026028,0.929459825175222,0.929762000086221,0.930062880562141,0.930362472147987,1)

# %%
plot(y~x)
# Out:
# plot without title

# %%
x<-c(0,2.75,5.5,8.25,11,13.75,16.5,19.25,22,24.75,27.5,27.5,30,32.5,35,37.5,40,42.5,45,47.5,50,52.5,55,57.5,61.75,66,70.25,74.5,78.75,83,87.25,91.5,95.75,100)
y<-c(0,0.147811177270805,0.148218217432002,0.148626378494174,0.149035663544041,0.149446075676825,0.149857617996268,0.150270293614661,0.150684105652867,0.151099057240339,0.151515151515152,0.151515151515152,0.303030303030303,0.363636363636364,0.424242424242424,0.484848484848485,0.545454545454545,0.575757575757576,0.606060606060606,0.636363636363636,0.666666666666667,0.727272727272727,0.787878787878788,0.893939393939394,0.894389195010831,0.894837088484231,0.895283082449683,0.895727184962964,0.896169404045689,0.896609747685452,0.897048223835971,0.897484840417234,0.89791960531564,1)

# %%
plot(y~x)
# Out:
# plot without title

# %%
library(scam)
# Out:
# Loading required package: mgcv
#
# Loading required package: nlme
#
# This is mgcv 1.9-1. For overview type 'help("mgcv-package")'.
#
# This is scam 1.2-18.

# %%
x<-c(0,2.75,5.5,8.25,11,13.75,16.5,19.25,22,24.75,27.5,27.5,30,32.5,35,37.5,40,42.5,45,47.5,50,52.5,55,57.5,61.75,66,70.25,74.5,78.75,83,87.25,91.5,95.75,100)
y<-c(0,0.0127519682208046,0.0167883573276263,0.0221023874024587,0.0290984710031446,0.0383090296673858,0.0504350126815272,0.0663992412825681,0.0874166379364374,0.115086685337116,0.151515151515152,0.151515151515152,0.303030303030303,0.363636363636364,0.424242424242424,0.484848484848485,0.545454545454545,0.575757575757576,0.606060606060606,0.636363636363636,0.666666666666667,0.727272727272727,0.787878787878788,0.893939393939394,0.930660780365016,0.954668113278165,0.970363382158336,0.98062447472168,0.987332867002015,0.991718611181696,0.994585878211681,0.996460410761784,0.997685923504283,1)

# %%
plot(y~x)
# Out:
# plot without title

# %%
cdf_bspline_fit <- scam(y ~ s(x, bs = "mpi"))

# %%
x
# Out:
#  [1]   0.00   2.75   5.50   8.25  11.00  13.75  16.50  19.25  22.00  24.75
# [11]  27.50  27.50  30.00  32.50  35.00  37.50  40.00  42.50  45.00  47.50
# [21]  50.00  52.50  55.00  57.50  61.75  66.00  70.25  74.50  78.75  83.00
# [31]  87.25  91.50  95.75 100.00

# %%
new_data<-seq(0,100,length.out=100) # Fit it to new data

# %%
length(x)
# Out:
# [1] 34

# %%
bspline_cdf <- function(x) {
pdf_values <- predict(cdf_bspline_fit,newdata = data.frame(x=new_data))
}

# %%
library("ggplot2")

# %%
pdf_values <- predict(cdf_bspline_fit,newdata = data.frame(x=new_data))

# %%
df_pred<-data.frame(cdf.values=pdf_values,new_data=new_data)

# %%
head(df_pred)
# Out:
#   cdf.values  new_data
# 1 0.005217871 0.000000
# 2 0.005245174 1.010101
# 3 0.005334145 2.020202
# 4 0.005546312 3.030303
# 5 0.005943204 4.040404
# 6 0.006586349 5.050505

# %%
# Plot the original data + fitted function using stat_function
ggplot()+# Original data points
  geom_line(data = df_pred, aes(x = new_data, y = cdf.values), color = "red", size = 1) +
  labs(title = "CDF B-Spline Fit", x = "Extended Values", y = "Cumulative Sums") +
  theme_minimal()
# Out:
# plot without title

# %%
x<-c(0,0.251677852348993,0.503355704697987,0.75503355704698,1.00671140939597,1.25838926174497,1.51006711409396,1.76174496644295,2.01342281879195,2.26510067114094,2.51677852348993,2.76845637583893,3.02013422818792,3.27181208053691,3.52348993288591,3.7751677852349,4.02684563758389,4.27852348993289,4.53020134228188,4.78187919463087,5.03355704697987,5.28523489932886,5.53691275167785,5.78859060402685,6.04026845637584,6.29194630872483,6.54362416107383,6.79530201342282,7.04697986577181,7.29865771812081,7.5503355704698,7.80201342281879,8.05369127516779,8.30536912751678,8.55704697986577,8.80872483221477,9.06040268456376,9.31208053691275,9.56375838926175,9.81543624161074,10.0671140939597,10.3187919463087,10.5704697986577,10.8221476510067,11.0738255033557,11.3255033557047,11.5771812080537,11.8288590604027,12.0805369127517,12.3322147651007,12.5838926174497,12.8355704697987,13.0872483221477,13.3389261744966,13.5906040268456,13.8422818791946,14.0939597315436,14.3456375838926,14.5973154362416,14.8489932885906,15.1006711409396,15.3523489932886,15.6040268456376,15.8557046979866,16.1073825503356,16.3590604026846,16.6107382550336,16.8624161073826,17.1140939597315,17.3657718120805,17.6174496644295,17.8691275167785,18.1208053691275,18.3724832214765,18.6241610738255,18.8758389261745,19.1275167785235,19.3791946308725,19.6308724832215,19.8825503355705,20.1342281879195,20.3859060402685,20.6375838926175,20.8892617449664,21.1409395973154,21.3926174496644,21.6442953020134,21.8959731543624,22.1476510067114,22.3993288590604,22.6510067114094,22.9026845637584,23.1543624161074,23.4060402684564,23.6577181208054,23.9093959731544,24.1610738255034,24.4127516778524,24.6644295302013,24.9161073825503,25.1677852348993,25.4194630872483,25.6711409395973,25.9228187919463,26.1744966442953,26.4261744966443,26.6778523489933,26.9295302013423,27.1812080536913,27.4328859060403,27.6845637583893,27.9362416107383,28.1879194630873,28.4395973154362,28.6912751677852,28.9429530201342,29.1946308724832,29.4463087248322,29.6979865771812,29.9
913525,0.981768242221707,0.981814069824975,0.981859782235334,0.981905379742334,0.981950862634798,0.981996231200822,0.982041485727779,0.98208662650232,0.982131653810374,0.982176567937151,0.982221369167147,0.98226605778414,0.982310634071195,0.982355098310667,0.9823994507842,0.98244369177273,0.982487821556489,0.982531840415001,0.98257574862709,0.982619546470878,0.982663234223789,0.982706812162549,0.982750280563187,0.982793639701042,0.982836889850756,0.982880031286285,0.982923064280893,0.98296598910716,0.983008806036978,0.983051515341558,0.983094117291429,0.983136612156438,0.983179000205755,0.983221281707875,0.983263456930614,0.98330552614112,0.983347489605865,0.983389347590654,0.983431100360623,0.98347274818024,0.983514291313312,0.983555730022978,0.98359706457172,0.983638295221358,0.983679422233054,0.983720445867314,0.983761366383988,0.983802184042275,0.983842899100722,0.983883511817223,0.983924022449028,0.983964431252738,0.98400473848431,0.984044944399056,0.984085049251648,0.984125053296118,0.984164956785858,0.984204759973624,0.984244463111536,0.984284066451081,0.984323570243114,0.984362974737858,0.98440228018491,0.984441486833235,0.984480594931177,0.984519604726453,0.984558516466158,0.984597330396765,0.98463604676413,0.984674665813488,0.984713187789459,0.984751612936049,0.984789941496648,0.984828173714038,0.984866309830387,0.984904350087257,0.984942294725601,0.984980143985768,0.9850178981075,0.985055557329941,0.985093121891629,0.985130592030505,0.985167967983913,0.985205249988597,0.985242438280709,0.985279533095806,0.985316534668852,0.985353443234224,0.985390259025705,0.985426982276494,0.985463613219203,0.985500152085858,0.985536599107902,0.985572954516198,0.985609218541028,0.985645391412094,1)

# %%
plot(y~x)
# Out:
# plot without title

# %%
?approx
# Out:
# approxfun                package:stats                 R Documentation
#
# s
#
# n:
#
#      Return a list of points which linearly interpolate given data
#      points, or a function performing the linear (or constant)
#      interpolation.
#
# e:
#
#      approx   (x, y = NULL, xout, method = "linear", n = 50,
#                yleft, yright, rule = 1, f = 0, ties = mean, na.rm = TRUE)
#
#      approxfun(x, y = NULL,       method = "linear",
#                yleft, yright, rule = 1, f = 0, ties = mean, na.rm = TRUE)
#
# s:
#
#     x, y: numeric vectors giving the coordinates of the points to be
#           interpolated.  Alternatively a single plotting structure can
#           be specified: see ‘xy.coords’.
#
#     xout: an optional set of numeric values specifying where
#           interpolation is to take place.
#
#   method: specifies the interpolation method to be used.  Choices are
#           ‘"linear"’ or ‘"constant"’.
#
# ...

# %%
?optim
# Out:
# optim                  package:stats                   R Documentation
#
# n
#
# n:
#
#      General-purpose optimization based on Nelder-Mead, quasi-Newton
#      and conjugate-gradient algorithms. It includes an option for
#      box-constrained optimization and simulated annealing.
#
# e:
#
#      optim(par, fn, gr = NULL, ...,
#            method = c("Nelder-Mead", "BFGS", "CG", "L-BFGS-B", "SANN",
#                       "Brent"),
#            lower = -Inf, upper = Inf,
#            control = list(), hessian = FALSE)
#
#      optimHess(par, fn, gr = NULL, ..., control = list())
#
# s:
#
#      par: Initial values for the parameters to be optimized over.
#
#       fn: A function to be minimized (or maximized), with first
#           argument the vector of parameters over which minimization is
#           to take place.  It should return a scalar result.
#
#       gr: A function to return the gradient for the ‘"BFGS"’, ‘"CG"’
# ...
